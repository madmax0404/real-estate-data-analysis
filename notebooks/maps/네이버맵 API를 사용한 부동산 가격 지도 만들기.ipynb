# %%
import pandas as pd
import numpy as np
import os
import requests
from PIL import Image
from io import BytesIO

# %%
map_url = 'https://naveropenapi.apigw.ntruss.com/map-static/v2/raster?w=1000&h=1000&center=126.97499964422883,37.564657444970775&level=10'

# %%
id_header = 'X-NCP-APIGW-API-KEY-ID'
map_id = 'jspmtmzr7t'
key_header = 'X-NCP-APIGW-API-KEY'
map_key = 'AsEv6b3V7j6DOgLzqgRL9B3ta3dYikCQBog0nNXp'

# %%
map_headers = {id_header:map_id, key_header:map_key}

# %%
r = requests.get(url=map_url, headers=map_headers)

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://naveropenapi.apigw.ntruss.com/map-static/v2/raster?w=1000&h=1000&center=126.97499964422883,37.564657444970775&level=10'

# %%
Image.open(BytesIO(r.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x133989C1508>

# %%
r.close()
